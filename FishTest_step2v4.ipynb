# %% [markdown]
# #For deleting
# import shutil
# LOGS_DIR = BASE_PATH.joinpath("wandb")
# if LOGS_DIR.exists():
#     shutil.rmtree(LOGS_DIR)
# print (str(LOGS_DIR.absolute()))

# %% [markdown]
# step2v4 = data augmentation - brightness, contrast, hue, saturation and quality more adjusted not including masks

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import keras
import os
import cv2
import pathlib
import datetime
import wandb
from wandb.keras import WandbCallback
BASE_PATH = pathlib.Path(".")
os.environ['WANDB_API_KEY'] = 'local-f29e3da86585769dd70643a027ab5817d34b1b6a'  
os.environ['WANDB_BASE_URL'] = 'https://wandb.ikt-lab.internal.uia.no/'

PROJECT_NAME="FishTest_aug"

# %%
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: benteb13. Use `wandb login --relogin` to force relogin
# True

# %%
dir0 = BASE_PATH.joinpath('Fish_Dataset/Fish_Dataset')
files =[]
paths = []
classes_paths = [x for x in list (dir0.glob("**/*")) if "GT" not in x.name and not x.name.startswith("_") and not x.name.startswith(".") and x.is_dir()]
for class_path in classes_paths:
    class_images = list(class_path.glob("*.png"))
    class_names = [x.name for x in class_images]
    files.extend(class_names)
    paths.extend([str(x.absolute()) for x in class_images])

# %%
dir1 = BASE_PATH.joinpath('Fish_Dataset/Fish_Dataset')
mfiles =[]
mpaths = []
classes_paths = [x for x in list (dir0.glob("**/*")) if "GT" in x.name and not x.name.startswith("_") and not x.name.startswith(".") and x.is_dir()]
for class_path in classes_paths:
    class_images = list(class_path.glob("*.png"))
    class_names = [x.name for x in class_images]
    mfiles.extend(class_names)
    mpaths.extend([str(x.absolute()) for x in class_images])

# %%
df0 = pd.DataFrame(columns = ['label','file','path','mpath'])
df0['label'] = 1
df0['file'] = files
df0['path'] = paths
df0['mpath'] = mpaths

display(df0)
# Out:
#       label       file                                               path  \
# 0       NaN  00751.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 1       NaN  00200.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 2       NaN  00553.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 3       NaN  00842.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 4       NaN  00064.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# ...     ...        ...                                                ...
# 8995    NaN  00520.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8996    NaN  00796.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8997    NaN  00026.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8998    NaN  00963.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8999    NaN  00733.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
#
#                                                   mpath
# 0     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 1     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 2     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 3     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 4     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# ...                                                 ...
# 8995  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8996  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8997  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8998  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8999  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
#
# [9000 rows x 4 columns]

# %%
#Display image from dataset
path0=df0.loc[0,'path']
img0=cv2.imread(path0,cv2.IMREAD_GRAYSCALE)
shape0=img0.shape
print(shape0)
plt.imshow(img0)
plt.show()

#Display mask from dataset
path1=df0.loc[0,'mpath']
img1=cv2.imread(path1,cv2.IMREAD_GRAYSCALE)
shape1=img1.shape
print(shape1)
plt.imshow(img1)
plt.show()
# Out:
# (445, 590)
# (445, 590)

# %% [markdown]
# #### Train/test data settings:

# %%
option_train = True
img_size = [256,256]
BATCH_SIZE = 16
BUFFER_SIZE = 1000
EPOCHS = 150
seed = (1, 2)

df = df0.iloc[0:(len(df0)//10)*3]
train_size = 0.6
validate_size = 0.2
train_df, valid_df, test_df = np.split(df.sample(frac=1), [int(train_size * len(df)), int((validate_size + train_size) * len(df))])

TRAIN_LENGTH = len(train_df)
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
def data_augmentation(fish_img, mask_img):
    if tf.random.uniform(()) > 0.5:
        fish_img = tf.image.flip_left_right(fish_img)
        mask_img = tf.image.flip_left_right(mask_img)
    return fish_img, mask_img

def random_bright(fish_img, mask_img):
    fish_img = tf.image.stateless_random_brightness(fish_img, 0.4, seed)
    #mask_img = tf.image.stateless_random_brightness(mask_img, 0.2, seed)   
    return fish_img, mask_img

def random_contrast(fish_img, mask_img):
    fish_img = tf.image.stateless_random_contrast(fish_img, 0.1, 0.5, seed)
    #mask_img = tf.image.stateless_random_contrast(mask_img, 0.2, 0.5,  seed)   
    return fish_img, mask_img

def random_quality(fish_img, mask_img):
    fish_img = tf.image.stateless_random_jpeg_quality(fish_img, 55, 100, seed)
    #mask_img = tf.image.stateless_random_jpeg_quality(mask_img, 75, 100, seed)
    return fish_img, mask_img

def random_sat(fish_img, mask_img):
    fish_img = tf.image.stateless_random_saturation(fish_img, 0.5, 1.0, seed)
    #mask_img = tf.image.stateless_random_saturation(mask_img, 0.2, seed)   
    return fish_img, mask_img

def random_hue(fish_img, mask_img):
    fish_img = tf.image.stateless_random_hue(fish_img, 0.4, seed)
    #mask_img = tf.image.stateless_random_saturation(mask_img, 0.2, seed)   
    return fish_img, mask_img


def preprocessing(fish_path, mask_path):
    fish_img = tf.io.read_file(fish_path) 
    fish_img = tf.image.decode_jpeg(fish_img, channels=3)
    fish_img = tf.image.resize(fish_img, img_size)
    fish_img = tf.cast(fish_img, tf.float32) / 255.0
    
    mask_img = tf.io.read_file(mask_path)
    mask_img = tf.image.decode_jpeg(mask_img, channels=3)
    mask_img = tf.image.resize(mask_img, img_size)
    mask_img = mask_img[:,:,:1]    
    mask_img = tf.math.sign(mask_img)    
    return fish_img, mask_img

def create_dataset(df, train = False):
    if not train:
        ds = tf.data.Dataset.from_tensor_slices((df["path"].values, df["mpath"].values))
        ds = ds.map(preprocessing, tf.data.AUTOTUNE)
    else:
        ds = tf.data.Dataset.from_tensor_slices((df["path"].values, df["mpath"].values))
        ds = ds.map(preprocessing, tf.data.AUTOTUNE)
        ds = ds.map(data_augmentation, tf.data.AUTOTUNE)           
        ds = ds.map(random_bright, tf.data.AUTOTUNE)
        ds = ds.map(random_contrast, tf.data.AUTOTUNE)
        ds = ds.map(random_quality, tf.data.AUTOTUNE)
        ds = ds.map(random_sat, tf.data.AUTOTUNE)
        ds = ds.map(random_hue, tf.data.AUTOTUNE)
    return ds

# %%
train = create_dataset(train_df, train = True)
valid = create_dataset(valid_df)
test = create_dataset(test_df)

train_dataset = train.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
valid_dataset = valid.batch(BATCH_SIZE)
test_dataset = test.batch(BATCH_SIZE)
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# 2023-02-13 11:03:17.222655: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30996 MB memory:  -> device: 0, name: Tesla V100-SXM3-32GB, pci bus id: 0000:5e:00.0, compute capability: 7.0
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.

# %% [markdown]
# #### MobileNetV2 Model

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[256,256,3], include_top=False)

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
    ]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)
down_stack.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
def upsample(filters, size, norm_type='batchnorm', apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)    
    result = tf.keras.Sequential()
    result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2, padding='same', kernel_initializer=initializer, use_bias=False))

    if norm_type.lower() == 'batchnorm':
        result.add(tf.keras.layers.BatchNormalization())
    elif norm_type.lower() == 'instancenorm':
        result.add(InstanceNormalization())
    if apply_dropout:
        result.add(tf.keras.layers.Dropout(0.5))
        result.add(tf.keras.layers.ReLU())
    return result

up_stack = [
    upsample(512, 3),  # 4x4 -> 8x8
    upsample(256, 3),  # 8x8 -> 16x16
    upsample(128, 3),  # 16x16 -> 32x32
    upsample(64, 3),   # 32x32 -> 64x64
    ]

# %%
def unet_model(output_channels):
    inputs = tf.keras.layers.Input(shape=[256,256,3])

  # Downsampling through the model
    skips = down_stack(inputs)
    x = skips[-1]
    skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        concat = tf.keras.layers.Concatenate()
        x = concat([x, skip])

  # This is the last layer of the model
    last = tf.keras.layers.Conv2DTranspose(
      output_channels, 3, strides=2, activation='sigmoid',
      padding='same')  #64x64 -> 128x128
    x = last(x)
    
    return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# #### Train the model

# %%
def dice(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

def dice_loss(in_gt, in_pred):
    return 1 - dice(in_gt, in_pred)

def iou(y_true, y_pred):
    y_true = tf.keras.backend.flatten(y_true)
    y_pred = tf.keras.backend.flatten(y_pred)
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred, tf.float32)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    union = tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection
    return (intersection + 1e-7) / (union + 1e-7)

def iou_loss(y_true, y_pred):
    return 1.0 - iou(y_true, y_pred)

# %%
def visualize(display_list):
    plt.figure(figsize=(12,12))
    title = ['Input Image', 'Predicted Mask', 'True Mask']
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

def show_predictions(model, sample_image, sample_mask):
    pred_mask = model.predict(sample_image[tf.newaxis, ...])
    pred_mask = pred_mask.reshape(img_size[0],img_size[1],1)
    visualize([sample_image, pred_mask, sample_mask])

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if (epoch + 1) % 3 == 0:
            show_predictions(sample_image, sample_mask)
            
model_config = dict(
    unet_model_iou = [lambda *args: unet_model(*args), [iou_loss], [iou, "binary_accuracy"], "adam" , 1],
    unet_model_dice = [lambda *args: unet_model(*args), [dice_loss], [dice, "binary_accuracy"], "adam" , 1]
)

for model_name, (model_fn, model_loss, model_metrics, model_loss_fn, batch_size) in model_config.items():
    experiment_name = f"{model_name}_{str(datetime.datetime.now())}"
    experiment_path = pathlib.Path(f"./logs/{experiment_name}")
    checkpoint_name = f"{model_name}"
    checkpoint_path = pathlib.Path(f"./checkpoints/{checkpoint_name}")
    model = model_fn(1)
    model.compile(optimizer= model_loss_fn,
                  loss = model_loss,
                  metrics= model_metrics)            
    if option_train:
        run = wandb.init(reinit = True , name = experiment_name , project = PROJECT_NAME, config = {
                  #"learning_rate": 0.001,
                  "epochs": EPOCHS ,
                  "batch_size": batch_size,
                  "optimizer" : model_loss_fn
        })        
        model_history = model.fit(train_dataset, epochs=EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              batch_size = batch_size, 
                              validation_data=valid_dataset,
                              callbacks=[
                                  #DisplayCallback(),
                                  WandbCallback(),
                                  tf.keras.callbacks.TensorBoard(log_dir=experiment_path,
                                                                 histogram_freq=0,
                                                                 write_graph=True,
                                                                 write_images=True),
                                  tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                                 save_weights_only=True,
                                                                 monitor="val_loss",
                                                                 save_best_only=True,
                                                                 mode='auto')                              
                              ])
        run.finish()
# Out:
# wandb version 0.13.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/home/benteb13/Fish/Test/wandb/run-20230213_110326-349wqm9z</code>
# Syncing run <strong><a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/349wqm9z" target="_blank">unet_model_iou_2023-02-13 11:03:26.020226</a></strong> to <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# 2023-02-13 11:03:26.950766: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 11:03:26.950824: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
# 2023-02-13 11:03:26.950929: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1630] Profiler found 1 GPUs
# 2023-02-13 11:03:27.176959: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 11:03:27.177224: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/150
# 2023-02-13 11:03:34.013050: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
#   1/101 [..............................] - ETA: 13:28 - loss: 0.8354 - iou: 0.1646 - binary_accuracy: 0.6661
# 2023-02-13 11:03:35.527472: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 11:03:35.527509: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
#   2/101 [..............................] - ETA: 1:38 - loss: 0.8182 - iou: 0.1818 - binary_accuracy: 0.6408
# 2023-02-13 11:03:36.414309: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2023-02-13 11:03:36.414879: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# 2023-02-13 11:03:36.474996: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:526]  GpuTracer has collected 4865 callback api events and 3499 activity events.
# 2023-02-13 11:03:36.521951: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 11:03:36.587591: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/unet_model_iou_2023-02-13 11:03:26.020226/train/plugins/profile/2023_02_13_11_03_36
#   3/101 [..............................] - ETA: 1:07 - loss: 0.7989 - iou: 0.2011 - binary_accuracy: 0.6283
# 2023-02-13 11:03:36.632689: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to logs/unet_model_iou_2023-02-13 11:03:26.020226/train/plugins/profile/2023_02_13_11_03_36/jupyter-benteb13.trace.json.gz
ic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_110326-349wqm9z/files/model-best)... Done. 0.3s
# Epoch 4/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.1309 - iou: 0.8691 - binary_accuracy: 0.9762 - val_loss: 0.3412 - val_iou: 0.6586 - val_binary_accuracy: 0.9316
# Epoch 5/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.1243 - iou: 0.8759 - binary_accuracy: 0.9772 - val_loss: 0.3269 - val_iou: 0.6729 - val_binary_accuracy: 0.9333
# Epoch 6/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.1246 - iou: 0.8757 - binary_accuracy: 0.9770 - val_loss: 0.3215 - val_iou: 0.6783 - val_binary_accuracy: 0.9327
# Epoch 7/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.1204 - iou: 0.8789 - binary_accuracy: 0.9776 - val_loss: 0.2959 - val_iou: 0.7038 - val_binary_accuracy: 0.9350
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_110326-349wqm9z/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_110326-349wqm9z/files/model-best)... Done. 0.3s
# Epoch 8/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.1217 - iou: 0.8784 - binary_accuracy: 0.9775 - val_loss: 0.2963 - val_iou: 0.7035 - val_binary_accuracy: 0.9384
# Epoch 9/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.1176 - iou: 0.8826 - binary_accuracy: 0.9780 - val_loss: 0.3053 - val_iou: 0.6945 - val_binary_accuracy: 0.9352
# Epoch 10/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.1161 - iou: 0.8840 - binary_accuracy: 0.9782 - val_loss: 0.3146 - val_iou: 0.6852 - val_binary_accuracy: 0.9348
# Epoch 11/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.1134 - iou: 0.8868 - binary_accuracy: 0.9787 - val_loss: 0.3055 - val_iou: 0.6943 - val_binary_accuracy: 0.9345
# Epoch 12/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.1146 - iou: 0.8848 - binary_accuracy: 0.9785 - val_loss: 0.3173 - val_iou: 0.6825 - val_binary_accuracy: 0.9330
# Epoch 13/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.1136 - iou: 0.8864 - binary_accuracy: 0.9785 - val_loss: 0.3114 - val_iou: 0.6883 - val_binary_accuracy: 0.9336
# Epoch 14/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.1134 - iou: 0.8862 - binary_accuracy: 0.9787 - val_loss: 0.2876 - val_iou: 0.7121 - val_binary_accuracy: 0.9376
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_110326-349wqm9z/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_110326-349wqm9z/files/model-best)... Done. 0.3s
# Epoch 15/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.1097 - iou: 0.8905 - binary_accuracy: 0.9793 - val_loss: 0.3181 - val_iou: 0.6816 - val_binary_accuracy: 0.9314
# Epoch 16/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.1131 - iou: 0.8869 - binary_accuracy: 0.9787 - val_loss: 0.3119 - val_iou: 0.6879 - val_binary_accuracy: 0.9341
# Epoch 17/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0
150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0876 - iou: 0.9123 - binary_accuracy: 0.9833 - val_loss: 0.3952 - val_iou: 0.6046 - val_binary_accuracy: 0.9186
# Epoch 148/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0859 - iou: 0.9143 - binary_accuracy: 0.9837 - val_loss: 0.3779 - val_iou: 0.6219 - val_binary_accuracy: 0.9211
# Epoch 149/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0905 - iou: 0.9094 - binary_accuracy: 0.9828 - val_loss: 0.3754 - val_iou: 0.6244 - val_binary_accuracy: 0.9215
# Epoch 150/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0836 - iou: 0.9163 - binary_accuracy: 0.9841 - val_loss: 0.3824 - val_iou: 0.6174 - val_binary_accuracy: 0.9210
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>binary_accuracy</td><td>▁▃▄▄▄▅▅▆▅▆▅▆▆▆▆▆▆▇▇▇▇▆▇▇▇▇▇▇▇▇▇▇▇█▇▇▇▇▇█</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>iou</td><td>▁▃▄▅▅▅▆▆▆▆▆▆▆▆▇▆▇▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇█▇▇█</td></tr><tr><td>loss</td><td>█▆▅▄▄▄▃▃▃▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▂▂▁</td></tr><tr><td>val_binary_accuracy</td><td>▅▆█▆▆▅▆▆▄▅▄▃▂▅▄▃▅▄▄▁▂▄▃▃▃▂▃▂▂▄▂▃▃▂▂▂▃▃▃▂</td></tr><tr><td>val_iou</td><td>▇▅█▇▇▇▇▆▃▆▅▃▂▇▄▃▅▄▅▁▂▅▃▃▄▃▄▂▂▅▃▃▄▃▃▃▄▄▄▂</td></tr><tr><td>val_loss</td><td>▂▄▁▂▂▂▂▃▆▃▄▆▇▂▅▆▄▅▄█▇▄▆▆▅▆▅▇▇▄▆▆▅▆▆▆▅▅▅▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.28764</td></tr><tr><td>binary_accuracy</td><td>0.98406</td></tr><tr><td>epoch</td><td>149</td></tr><tr><td>iou</td><td>0.91626</td></tr><tr><td>loss</td><td>0.08359</td></tr><tr><td>val_binary_accuracy</td><td>0.92097</td></tr><tr><td>val_iou</td><td>0.61738</td></tr><tr><td>val_loss</td><td>0.38241</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">unet_model_iou_2023-02-13 11:03:26.020226</strong>: <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/349wqm9z" target="_blank">https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/349wqm9z</a><br/>Synced 5 W&B file(s), 1 media file(s), 16 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20230213_110326-349wqm9z/logs</code>
# Upgrade to the 0.27.0 version of W&B Server to get the latest features. Learn more: <a href="https://wandb.me/server-upgrade" target="_blank">https://wandb.me/server-upgrade</a>
# wandb version 0.13.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/home/benteb13/Fish/Test/wandb/run-20230213_111844-iowl8min</code>
# Syncing run <strong><a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/iowl8min" target="_blank">unet_model_dice_2023-02-13 11:18:43.796317</a></strong> to <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2023-02-13 11:18:49.704256: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 11:18:49.704319: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
# 2023-02-13 11:18:50.494647: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 11:18:50.494848: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# Epoch 1/150
#   1/101 [..............................] - ETA: 3:51 - loss: 0.8209 - dice: 0.1791 - binary_accuracy: 0.3063
# 2023-02-13 11:18:53.184761: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 11:18:53.184793: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
#   3/101 [..............................] - ETA: 57s - loss: 0.7817 - dice: 0.2183 - binary_accuracy: 0.3183
# 2023-02-13 11:18:54.082618: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2023-02-13 11:18:54.083381: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# 2023-02-13 11:18:54.138759: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:526]  GpuTracer has collected 411 callback api events and 409 activity events.
# 2023-02-13 11:18:54.149588: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 11:18:54.161703: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54
#
# 2023-02-13 11:18:54.169130: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54/jupyter-benteb13.trace.json.gz
# 2023-02-13 11:18:54.200406: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54
#
# 2023-02-13 11:18:54.205542: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54/jupyter-benteb13.memory_profile.json.gz
# 2023-02-13 11:18:54.206524: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54
# Dumped tool data for xplane.pb to logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54/jupyter-benteb13.xplane.pb
# Dumped tool data for overview_page.pb to logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54/jupyter-benteb13.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54/jupyter-benteb13.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54/jupyter-benteb13.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/unet_model_dice_2023-02-13 11:18:43.796317/train/plugins/profile/2023_02_13_11_18_54/jupyter-benteb13.kernel_stats.pb
#   5/101 [>.............................] - ETA: 30s - loss: 0.7473 - dice: 0.2527 - binary_accuracy: 0.3228WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0292s vs `on_train_batch_begin` time: 0.1003s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0292s vs `on_train_batch_end` time: 0.0919s). Check your callbacks.
# 101/101 [==============================] - 10s 73ms/step - loss: 0.1955 - dice: 0.8045 - binary_accuracy: 0.8929 - val_loss: 0.2093 - val_dice: 0.7905 - val_binary_accuracy: 0.9327
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_111844-iowl8min/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_111844-iowl8min/files/model-best)... Done. 0.3s
# Epoch 2/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.0677 - dice: 0.9324 - binary_accuracy: 0.9814 - val_loss: 0.2351 - val_dice: 0.7647 - val_binary_accuracy: 0.9255
# Epoch 3/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0623 - dice: 0.9376 - binary_accuracy: 0.9820 - val_loss: 0.2304 - val_dice: 0.7695 - val_binary_accuracy: 0.9251
# Epoch 4/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0588 - dice: 0.9413 - binary_accuracy: 0.9825 - val_loss: 0.2428 - val_dice: 0.7570 - val_binary_accuracy: 0.9219
# Epoch 5/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0578 - dice: 0.9416 - binary_accuracy: 0.9823 - val_loss: 0.2237 - val_dice: 0.7762 - val_binary_accuracy: 0.9254
# Epoch 6/150
# 101/101 [==============================] - 6s 56ms/step - loss: 0.0568 - dice: 0.9433 - binary_accuracy: 0.9825 - val_loss: 0.2382 - val_dice: 0.7617 - val_binary_accuracy: 0.9219
# Epoch 7/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0560 - dice: 0.9441 - binary_accuracy: 0.9825 - val_loss: 0.2339 - val_dice: 0.7659 - val_binary_accuracy: 0.9227
# Epoch 8/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0554 - dice: 0.9447 - binary_accuracy: 0.9825 - val_loss: 0.2308 - val_dice: 0.7691 - val_binary_accuracy: 0.9230
# Epoch 9/150
# 101/101 [==============================] - 6s 56ms/step - loss: 0.0542 - dice: 0.9460 - binary_accuracy: 0.9828 - val_loss: 0.2461 - val_dice: 0.7538 - val_binary_accuracy: 0.9194
# Epoch 10/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0544 - dice: 0.9457 - binary_accuracy: 0.9826 - val_loss: 0.2182 - val_dice: 0.7817 - val_binary_accuracy: 0.9227
# Epoch 11/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0531 - dice: 0.9470 - binary_accuracy: 0.9829 - val_loss: 0.2356 - val_dice: 0.7643 - val_binary_accuracy: 0.9223
# Epoch 12/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0530 - dice: 0.9472 - binary_accuracy: 0.9830 - val_loss: 0.2363 - val_dice: 0.7636 - val_binary_accuracy: 0.9218
# Epoch 13/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0524 - dice: 0.9476 - binary_accuracy: 0.9830 - val_loss: 0.2486 - val_dice: 0.7513 - val_binary_accuracy: 0.9191
# Epoch 14/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0520 - dice: 0.9481 - binary_accuracy: 0.9830 - val_loss: 0.2292 - val_dice: 0.7707 - val_binary_accuracy: 0.9224
# Epoch 15/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0528 - dice: 0.9472 - binary_accuracy: 0.9828 - val_loss: 0.2428 - val_dice: 0.7571 - val_binary_accuracy: 0.9211
# Epoch 16/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0516 - dice: 0.9485 - binary_accuracy: 0.9831 - val_loss: 0.2542 - val_dice: 0.7457 - val_binary_accuracy: 0.9183
# Epoch 17/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0498 - dice: 0.9503 - binary_accuracy: 0.9836 - val_loss: 0.2321 - val_dice: 0.7677 - val_binary_accuracy: 0.9218
# Epoch 18/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0534 - dice: 0.9463 - binary_accuracy: 0.9825 - val_loss: 0.2231 - val_dice: 0.7767 - val_binary_accuracy: 0.9246
# Epoch 19/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0507 - dice: 0.9494 - binary_accuracy: 0.9833 - val_loss: 0.2279 - val_dice: 0.7720 - val_binary_accuracy: 0.9218
# Epoch 20/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.0513 - dice: 0.9487 - binary_accuracy: 0.9832 - val_loss: 0.2360 - val_dice: 0.7639 - val_binary_accuracy: 0.9215
# Epoch 21/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0499 - dice: 0.9501 - binary_accuracy: 0.9833 - val_loss: 0.2217 - val_dice: 0.7781 - val_binary_accuracy: 0.9225
# Epoch 22/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0512 - dice: 0.9489 - binary_accuracy: 0.9831 - val_loss: 0.2325 - val_dice: 0.7674 - val_binary_accuracy: 0.9218
# Epoch 23/150
# ...
# Epoch 80/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0462 - dice: 0.9539 - binary_accuracy: 0.9841 - val_loss: 0.2339 - val_dice: 0.7659 - val_binary_accuracy: 0.9211
# Epoch 81/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.0452 - dice: 0.9542 - binary_accuracy: 0.9844 - val_loss: 0.2395 - val_dice: 0.7604 - val_binary_accuracy: 0.9204
# Epoch 82/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0463 - dice: 0.9537 - binary_accuracy: 0.9841 - val_loss: 0.2332 - val_dice: 0.7667 - val_binary_accuracy: 0.9204
# Epoch 83/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0463 - dice: 0.9533 - binary_accuracy: 0.9841 - val_loss: 0.2209 - val_dice: 0.7789 - val_binary_accuracy: 0.9235
# Epoch 84/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0461 - dice: 0.9540 - binary_accuracy: 0.9841 - val_loss: 0.2355 - val_dice: 0.7644 - val_binary_accuracy: 0.9219
# Epoch 85/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0446 - dice: 0.9555 - binary_accuracy: 0.9845 - val_loss: 0.2293 - val_dice: 0.7706 - val_binary_accuracy: 0.9226
# Epoch 86/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0458 - dice: 0.9543 - binary_accuracy: 0.9843 - val_loss: 0.2429 - val_dice: 0.7570 - val_binary_accuracy: 0.9201
# Epoch 87/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0462 - dice: 0.9532 - binary_accuracy: 0.9842 - val_loss: 0.2385 - val_dice: 0.7614 - val_binary_accuracy: 0.9205
# Epoch 88/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0448 - dice: 0.9553 - binary_accuracy: 0.9845 - val_loss: 0.2377 - val_dice: 0.7622 - val_binary_accuracy: 0.9211
# Epoch 89/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0464 - dice: 0.9536 - binary_accuracy: 0.9840 - val_loss: 0.2284 - val_dice: 0.7715 - val_binary_accuracy: 0.9226
# Epoch 90/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.0457 - dice: 0.9545 - binary_accuracy: 0.9843 - val_loss: 0.2357 - val_dice: 0.7642 - val_binary_accuracy: 0.9207
# Epoch 91/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0456 - dice: 0.9545 - binary_accuracy: 0.9843 - val_loss: 0.2479 - val_dice: 0.7520 - val_binary_accuracy: 0.9196
# Epoch 92/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.0449 - dice: 0.9551 - binary_accuracy: 0.9845 - val_loss: 0.2387 - val_dice: 0.7612 - val_binary_accuracy: 0.9209
# Epoch 93/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0449 - dice: 0.9551 - binary_accuracy: 0.9844 - val_loss: 0.2360 - val_dice: 0.7639 - val_binary_accuracy: 0.9210
# Epoch 94/150
# 101/101 [==============================] - 5s 55ms/step - loss: 0.0459 - dice: 0.9541 - binary_accuracy: 0.9842 - val_loss: 0.2322 - val_dice: 0.7677 - val_binary_accuracy: 0.9221
# Epoch 95/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0447 - dice: 0.9554 - binary_accuracy: 0.9846 - val_loss: 0.2333 - val_dice: 0.7666 - val_binary_accuracy: 0.9221
# Epoch 96/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0447 - dice: 0.9554 - binary_accuracy: 0.9846 - val_loss: 0.2319 - val_dice: 0.7680 - val_binary_accuracy: 0.9214
# Epoch 97/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0465 - dice: 0.9535 - binary_accuracy: 0.9840 - val_loss: 0.2342 - val_dice: 0.7657 - val_binary_accuracy: 0.9214
# Epoch 98/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0452 - dice: 0.9549 - binary_accuracy: 0.9844 - val_loss: 0.2305 - val_dice: 0.7694 - val_binary_accuracy: 0.9220
# Epoch 99/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0452 - dice: 0.9548 - binary_accuracy: 0.9844 - val_loss: 0.2376 - val_dice: 0.7623 - val_binary_accuracy: 0.9215
# Epoch 100/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0456 - dice: 0.9544 - binary_accuracy: 0.9843 - val_loss: 0.2397 - val_dice: 0.7601 - val_binary_accuracy: 0.9208
# Epoch 101/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.0449 - dice: 0.9552 - binary_accuracy: 0.9845 - val_loss: 0.2396 - val_dice: 0.7603 - val_binary_accuracy: 0.9211
# Epoch 102/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0446 - dice: 0.9554 - binary_accuracy: 0.9845 - val_loss: 0.2383 - val_dice: 0.7616 - val_binary_accuracy: 0.9209
# Epoch 103/150
# 101/101 [==============================] - 6s 56ms/step - loss: 0.0450 - dice: 0.9550 - binary_accuracy: 0.9845 - val_loss: 0.2302 - val_dice: 0.7697 - val_binary_accuracy: 0.9219
# Epoch 104/150
# 101/101 [==============================] - 5s 55ms/step - loss: 0.0452 - dice: 0.9548 - binary_accuracy: 0.9844 - val_loss: 0.2432 - val_dice: 0.7567 - val_binary_accuracy: 0.9204
# Epoch 105/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.0447 - dice: 0.9553 - binary_accuracy: 0.9846 - val_loss: 0.2349 - val_dice: 0.7650 - val_binary_accuracy: 0.9214
# Epoch 106/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0447 - dice: 0.9554 - binary_accuracy: 0.9846 - val_loss: 0.2466 - val_dice: 0.7533 - val_binary_accuracy: 0.9190
# Epoch 107/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0451 - dice: 0.9550 - binary_accuracy: 0.9844 - val_loss: 0.2346 - val_dice: 0.7653 - val_binary_accuracy: 0.9213
# Epoch 108/150
# 101/101 [==============================] - 5s 50ms/step - loss: 0.0445 - dice: 0.9556 - binary_accuracy: 0.9846 - val_loss: 0.2396 - val_dice: 0.7603 - val_binary_accuracy: 0.9203
# Epoch 109/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.0453 - dice: 0.9549 - binary_accuracy: 0.9843 - val_loss: 0.2252 - val_dice: 0.7747 - val_binary_accuracy: 0.9238
# Epoch 110/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0451 - dice: 0.9544 - binary_accuracy: 0.9845 - val_loss: 0.2329 - val_dice: 0.7670 - val_binary_accuracy: 0.9216
# Epoch 111/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0442 - dice: 0.9553 - binary_accuracy: 0.9846 - val_loss: 0.2419 - val_dice: 0.7580 - val_binary_accuracy: 0.9207
# Epoch 112/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0438 - dice: 0.9563 - binary_accuracy: 0.9848 - val_loss: 0.2403 - val_dice: 0.7596 - val_binary_accuracy: 0.9207
# Epoch 113/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0453 - dice: 0.9549 - binary_accuracy: 0.9844 - val_loss: 0.2261 - val_dice: 0.7738 - val_binary_accuracy: 0.9223
# Epoch 114/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0449 - dice: 0.9552 - binary_accuracy: 0.9845 - val_loss: 0.2438 - val_dice: 0.7561 - val_binary_accuracy: 0.9195
# Epoch 115/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0432 - dice: 0.9569 - binary_accuracy: 0.9850 - val_loss: 0.2358 - val_dice: 0.7641 - val_binary_accuracy: 0.9211
# Epoch 116/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0457 - dice: 0.9538 - binary_accuracy: 0.9843 - val_loss: 0.2268 - val_dice: 0.7731 - val_binary_accuracy: 0.9228
# Epoch 117/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0451 - dice: 0.9550 - binary_accuracy: 0.9844 - val_loss: 0.2293 - val_dice: 0.7706 - val_binary_accuracy: 0.9220
# Epoch 118/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0429 - dice: 0.9571 - binary_accuracy: 0.9851 - val_loss: 0.2383 - val_dice: 0.7616 - val_binary_accuracy: 0.9207
# Epoch 119/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0449 - dice: 0.9553 - binary_accuracy: 0.9846 - val_loss: 0.2422 - val_dice: 0.7577 - val_binary_accuracy: 0.9203
# Epoch 120/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0454 - dice: 0.9535 - binary_accuracy: 0.9843 - val_loss: 0.2304 - val_dice: 0.7695 - val_binary_accuracy: 0.9222
# Epoch 121/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.0438 - dice: 0.9562 - binary_accuracy: 0.9848 - val_loss: 0.2282 - val_dice: 0.7717 - val_binary_accuracy: 0.9222
# Epoch 122/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0443 - dice: 0.9557 - binary_accuracy: 0.9846 - val_loss: 0.2523 - val_dice: 0.7476 - val_binary_accuracy: 0.9188
# Epoch 123/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0443 - dice: 0.9557 - binary_accuracy: 0.9847 - val_loss: 0.2391 - val_dice: 0.7608 - val_binary_accuracy: 0.9207
# Epoch 124/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0427 - dice: 0.9574 - binary_accuracy: 0.9852 - val_loss: 0.2354 - val_dice: 0.7645 - val_binary_accuracy: 0.9211
# Epoch 125/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0455 - dice: 0.9547 - binary_accuracy: 0.9843 - val_loss: 0.2316 - val_dice: 0.7683 - val_binary_accuracy: 0.9225
# Epoch 126/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0442 - dice: 0.9559 - binary_accuracy: 0.9846 - val_loss: 0.2310 - val_dice: 0.7689 - val_binary_accuracy: 0.9225
# Epoch 127/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0432 - dice: 0.9569 - binary_accuracy: 0.9851 - val_loss: 0.2363 - val_dice: 0.7636 - val_binary_accuracy: 0.9211
# Epoch 128/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0447 - dice: 0.9553 - binary_accuracy: 0.9844 - val_loss: 0.2378 - val_dice: 0.7621 - val_binary_accuracy: 0.9208
# Epoch 129/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0422 - dice: 0.9578 - binary_accuracy: 0.9852 - val_loss: 0.2398 - val_dice: 0.7601 - val_binary_accuracy: 0.9202
# Epoch 130/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0467 - dice: 0.9529 - binary_accuracy: 0.9840 - val_loss: 0.2371 - val_dice: 0.7628 - val_binary_accuracy: 0.9212
# Epoch 131/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0427 - dice: 0.9574 - binary_accuracy: 0.9852 - val_loss: 0.2392 - val_dice: 0.7607 - val_binary_accuracy: 0.9207
# Epoch 132/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.0452 - dice: 0.9549 - binary_accuracy: 0.9844 - val_loss: 0.2347 - val_dice: 0.7652 - val_binary_accuracy: 0.9225
# Epoch 133/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0437 - dice: 0.9564 - binary_accuracy: 0.9849 - val_loss: 0.2363 - val_dice: 0.7636 - val_binary_accuracy: 0.9214
# Epoch 134/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0416 - dice: 0.9585 - binary_accuracy: 0.9854 - val_loss: 0.2526 - val_dice: 0.7473 - val_binary_accuracy: 0.9181
# Epoch 135/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0444 - dice: 0.9558 - binary_accuracy: 0.9848 - val_loss: 0.2330 - val_dice: 0.7669 - val_binary_accuracy: 0.9214
# Epoch 136/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0449 - dice: 0.9551 - binary_accuracy: 0.9844 - val_loss: 0.2321 - val_dice: 0.7678 - val_binary_accuracy: 0.9220
# Epoch 137/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0440 - dice: 0.9560 - binary_accuracy: 0.9847 - val_loss: 0.2356 - val_dice: 0.7643 - val_binary_accuracy: 0.9215
# Epoch 138/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0422 - dice: 0.9573 - binary_accuracy: 0.9852 - val_loss: 0.2301 - val_dice: 0.7698 - val_binary_accuracy: 0.9222
# Epoch 139/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0439 - dice: 0.9558 - binary_accuracy: 0.9849 - val_loss: 0.2335 - val_dice: 0.7664 - val_binary_accuracy: 0.9221
# Epoch 140/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0424 - dice: 0.9578 - binary_accuracy: 0.9853 - val_loss: 0.2363 - val_dice: 0.7636 - val_binary_accuracy: 0.9210
# Epoch 141/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0448 - dice: 0.9547 - binary_accuracy: 0.9845 - val_loss: 0.2394 - val_dice: 0.7605 - val_binary_accuracy: 0.9196
# Epoch 142/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0434 - dice: 0.9567 - binary_accuracy: 0.9850 - val_loss: 0.2339 - val_dice: 0.7660 - val_binary_accuracy: 0.9218
# Epoch 143/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.0451 - dice: 0.9549 - binary_accuracy: 0.9844 - val_loss: 0.2402 - val_dice: 0.7596 - val_binary_accuracy: 0.9203
# Epoch 144/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0429 - dice: 0.9559 - binary_accuracy: 0.9851 - val_loss: 0.2443 - val_dice: 0.7556 - val_binary_accuracy: 0.9202
# Epoch 145/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0442 - dice: 0.9559 - binary_accuracy: 0.9847 - val_loss: 0.2391 - val_dice: 0.7609 - val_binary_accuracy: 0.9210
# Epoch 146/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.0432 - dice: 0.9569 - binary_accuracy: 0.9850 - val_loss: 0.2279 - val_dice: 0.7720 - val_binary_accuracy: 0.9224
# Epoch 147/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.0437 - dice: 0.9563 - binary_accuracy: 0.9849 - val_loss: 0.2356 - val_dice: 0.7643 - val_binary_accuracy: 0.9216
# Epoch 148/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0427 - dice: 0.9574 - binary_accuracy: 0.9851 - val_loss: 0.2443 - val_dice: 0.7556 - val_binary_accuracy: 0.9194
# Epoch 149/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.0452 - dice: 0.9548 - binary_accuracy: 0.9844 - val_loss: 0.2318 - val_dice: 0.7681 - val_binary_accuracy: 0.9218
# Epoch 150/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.0428 - dice: 0.9572 - binary_accuracy: 0.9851 - val_loss: 0.2357 - val_dice: 0.7642 - val_binary_accuracy: 0.9208
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>binary_accuracy</td><td>▁▃▃▄▄▄▅▄▅▅▅▅▅▅▅▆▆▅▅▅▅▆▆▆▆▆▆▆▇▇▆▇▇▇▆██▇▇▇</td></tr><tr><td>dice</td><td>▁▃▄▅▅▅▆▅▆▆▆▆▆▆▆▇▇▆▆▇▆▇▇▇▇▇▇▇▇▇▇█▇▇▇█████</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▄▄▃▄▃▃▃▃▃▃▃▂▂▃▃▂▃▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁</td></tr><tr><td>val_binary_accuracy</td><td>█▅▆▅▁▄▄▅▂▆▅▅▃▅▆▆▄▂▅▂▄▄▅▄▄▄▄▃▃▃▂▃▂▅▄▁▅▄▅▄</td></tr><tr><td>val_dice</td><td>▅▄▆▅▁▅▅▇▁█▇▇▄▇█▇▅▃▆▂▆▆▅▅▄▆▄▃▄▄▃▅▁▆▅▁▆▆▇▅</td></tr><tr><td>val_loss</td><td>▄▅▃▄█▄▄▂█▁▂▂▅▂▁▂▄▆▃▇▃▃▄▄▅▃▅▆▅▅▆▄█▃▄█▃▃▂▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>0.20927</td></tr><tr><td>binary_accuracy</td><td>0.98508</td></tr><tr><td>dice</td><td>0.95723</td></tr><tr><td>epoch</td><td>149</td></tr><tr><td>loss</td><td>0.04282</td></tr><tr><td>val_binary_accuracy</td><td>0.92081</td></tr><tr><td>val_dice</td><td>0.76421</td></tr><tr><td>val_loss</td><td>0.23571</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">unet_model_dice_2023-02-13 11:18:43.796317</strong>: <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/iowl8min" target="_blank">https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/iowl8min</a><br/>Synced 5 W&B file(s), 1 media file(s), 4 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20230213_111844-iowl8min/logs</code>
# Upgrade to the 0.27.0 version of W&B Server to get the latest features. Learn more: <a href="https://wandb.me/server-upgrade" target="_blank">https://wandb.me/server-upgrade</a>

# %%
model.load_weights(checkpoint_path)

# %%
#Show sample images in test dataset with their true mask and predicted mask after training
for i in range(5):
    for images, masks in test_dataset.take(i):
        for img, mask in zip(images, masks):
            tsample_image = img
            tsample_mask = mask
            show_predictions(model, tsample_image, tsample_mask)
            break

# %% [markdown]
# # Step 2

# %% [markdown]
# Use pre-trained model to predict fish in the wild

# %%
nor_fish_path = BASE_PATH.joinpath('Fish_Dataset/Norsk_Fisk')

nf_files =[]
nf_paths = []
nf_classes_paths = [x for x in list (nor_fish_path.glob("**/*")) if not x.name.startswith("_") and not x.name.startswith(".") and x.is_dir()]
for nf_class_path in nf_classes_paths:
    nf_class_images = list(nf_class_path.glob("*.PNG"))
    nf_class_names = [x.name for x in nf_class_images]
    nf_files.extend(nf_class_names)
    nf_paths.extend([str(x.absolute()) for x in nf_class_images])

# %%
nf_df = pd.DataFrame()
nf_df['label'] = 1
nf_df['file'] = nf_files
nf_df['path'] = nf_paths
nf_df['mpath'] = nf_paths

display(nf_df)
# Out:
#       label      file                                               path  \
# 0       NaN   128.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1       NaN    13.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 2       NaN   185.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 3       NaN    50.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 4       NaN    99.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# ...     ...       ...                                                ...
# 1304    NaN  4-11.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1305    NaN  4-21.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1306    NaN   4-8.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1307    NaN  4-17.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1308    NaN  4-25.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
#
#                                                   mpath
# 0     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 2     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 3     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 4     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# ...                                                 ...
# 1304  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1305  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1306  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1307  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1308  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
#
# [1309 rows x 4 columns]

# %%
nf_dataset = create_dataset(nf_df, train = False)

for i in range(5):
    for images, masks in nf_dataset.take(i):        
        pred_mask = model.predict(images[tf.newaxis, ...])
        pred_mask = pred_mask.reshape(img_size[0],img_size[1],1)
        visualize([images, pred_mask])
