# %% [markdown]
# #For deleting
# import shutil
# LOGS_DIR = BASE_PATH.joinpath("wandb")
# if LOGS_DIR.exists():
#     shutil.rmtree(LOGS_DIR)
# print (str(LOGS_DIR.absolute()))

# %% [markdown]
# step2v5 = data augmentation - brightness, contrast, hue, saturation and quality more adjusted including masks

# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import keras.backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import keras
import os
import cv2
import pathlib
import datetime
import wandb
from wandb.keras import WandbCallback
BASE_PATH = pathlib.Path(".")
os.environ['WANDB_API_KEY'] = 'local-f29e3da86585769dd70643a027ab5817d34b1b6a'  
os.environ['WANDB_BASE_URL'] = 'https://wandb.ikt-lab.internal.uia.no/'

PROJECT_NAME="FishTest_aug"

# %%
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: benteb13. Use `wandb login --relogin` to force relogin
# True

# %%
dir0 = BASE_PATH.joinpath('Fish_Dataset/Fish_Dataset')
files =[]
paths = []
classes_paths = [x for x in list (dir0.glob("**/*")) if "GT" not in x.name and not x.name.startswith("_") and not x.name.startswith(".") and x.is_dir()]
for class_path in classes_paths:
    class_images = list(class_path.glob("*.png"))
    class_names = [x.name for x in class_images]
    files.extend(class_names)
    paths.extend([str(x.absolute()) for x in class_images])

# %%
dir1 = BASE_PATH.joinpath('Fish_Dataset/Fish_Dataset')
mfiles =[]
mpaths = []
classes_paths = [x for x in list (dir0.glob("**/*")) if "GT" in x.name and not x.name.startswith("_") and not x.name.startswith(".") and x.is_dir()]
for class_path in classes_paths:
    class_images = list(class_path.glob("*.png"))
    class_names = [x.name for x in class_images]
    mfiles.extend(class_names)
    mpaths.extend([str(x.absolute()) for x in class_images])

# %%
df0 = pd.DataFrame(columns = ['label','file','path','mpath'])
df0['label'] = 1
df0['file'] = files
df0['path'] = paths
df0['mpath'] = mpaths

display(df0)
# Out:
#       label       file                                               path  \
# 0       NaN  00751.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 1       NaN  00200.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 2       NaN  00553.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 3       NaN  00842.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 4       NaN  00064.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# ...     ...        ...                                                ...
# 8995    NaN  00520.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8996    NaN  00796.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8997    NaN  00026.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8998    NaN  00963.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8999    NaN  00733.png  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
#
#                                                   mpath
# 0     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 1     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 2     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 3     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 4     /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# ...                                                 ...
# 8995  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8996  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8997  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8998  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
# 8999  /home/benteb13/Fish/Test/Fish_Dataset/Fish_Dat...
#
# [9000 rows x 4 columns]

# %%
#Display image from dataset
path0=df0.loc[0,'path']
img0=cv2.imread(path0,cv2.IMREAD_GRAYSCALE)
shape0=img0.shape
print(shape0)
plt.imshow(img0)
plt.show()

#Display mask from dataset
path1=df0.loc[0,'mpath']
img1=cv2.imread(path1,cv2.IMREAD_GRAYSCALE)
shape1=img1.shape
print(shape1)
plt.imshow(img1)
plt.show()
# Out:
# (445, 590)
# (445, 590)

# %% [markdown]
# #### Train/test data settings:

# %%
option_train = True
img_size = [256,256]
BATCH_SIZE = 16
BUFFER_SIZE = 1000
EPOCHS = 150
seed = (1, 2)

df = df0.iloc[0:(len(df0)//10)*3]
train_size = 0.6
validate_size = 0.2
train_df, valid_df, test_df = np.split(df.sample(frac=1), [int(train_size * len(df)), int((validate_size + train_size) * len(df))])

TRAIN_LENGTH = len(train_df)
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
def data_augmentation(fish_img, mask_img):
    if tf.random.uniform(()) > 0.5:
        fish_img = tf.image.flip_left_right(fish_img)
        mask_img = tf.image.flip_left_right(mask_img)
    return fish_img, mask_img

def random_bright(fish_img, mask_img):
    fish_img = tf.image.stateless_random_brightness(fish_img, 0.4, seed)
    mask_img = tf.image.stateless_random_brightness(mask_img, 0.2, seed)   
    return fish_img, mask_img

def random_contrast(fish_img, mask_img):
    fish_img = tf.image.stateless_random_contrast(fish_img, 0.1, 0.5, seed)
    mask_img = tf.image.stateless_random_contrast(mask_img, 0.2, 0.5,  seed)   
    return fish_img, mask_img

def random_quality(fish_img, mask_img):
    fish_img = tf.image.stateless_random_jpeg_quality(fish_img, 55, 100, seed)
    mask_img = tf.image.stateless_random_jpeg_quality(mask_img, 75, 100, seed)
    return fish_img, mask_img

def random_sat(fish_img, mask_img):
    fish_img = tf.image.stateless_random_saturation(fish_img, 0.5, 1.0, seed)
    #mask_img = tf.image.stateless_random_saturation(mask_img, 0.2, seed)   
    return fish_img, mask_img

def random_hue(fish_img, mask_img):
    fish_img = tf.image.stateless_random_hue(fish_img, 0.4, seed)
    #mask_img = tf.image.stateless_random_saturation(mask_img, 0.2, seed)   
    return fish_img, mask_img


def preprocessing(fish_path, mask_path):
    fish_img = tf.io.read_file(fish_path) 
    fish_img = tf.image.decode_jpeg(fish_img, channels=3)
    fish_img = tf.image.resize(fish_img, img_size)
    fish_img = tf.cast(fish_img, tf.float32) / 255.0
    
    mask_img = tf.io.read_file(mask_path)
    mask_img = tf.image.decode_jpeg(mask_img, channels=3)
    mask_img = tf.image.resize(mask_img, img_size)
    mask_img = mask_img[:,:,:1]    
    mask_img = tf.math.sign(mask_img)    
    return fish_img, mask_img

def create_dataset(df, train = False):
    if not train:
        ds = tf.data.Dataset.from_tensor_slices((df["path"].values, df["mpath"].values))
        ds = ds.map(preprocessing, tf.data.AUTOTUNE)
    else:
        ds = tf.data.Dataset.from_tensor_slices((df["path"].values, df["mpath"].values))
        ds = ds.map(preprocessing, tf.data.AUTOTUNE)
        ds = ds.map(data_augmentation, tf.data.AUTOTUNE)           
        ds = ds.map(random_bright, tf.data.AUTOTUNE)
        ds = ds.map(random_contrast, tf.data.AUTOTUNE)
        ds = ds.map(random_quality, tf.data.AUTOTUNE)
        ds = ds.map(random_sat, tf.data.AUTOTUNE)
        ds = ds.map(random_hue, tf.data.AUTOTUNE)
    return ds

# %%
train = create_dataset(train_df, train = True)
valid = create_dataset(valid_df)
test = create_dataset(test_df)

train_dataset = train.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
train_dataset = train_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
valid_dataset = valid.batch(BATCH_SIZE)
test_dataset = test.batch(BATCH_SIZE)
# Out:
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# 2023-02-13 11:47:47.974396: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30996 MB memory:  -> device: 0, name: Tesla V100-SXM3-32GB, pci bus id: 0000:5e:00.0, compute capability: 7.0
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.
# WARNING:tensorflow:The operation `tf.image.convert_image_dtype` will be skipped since the input and output dtypes are identical.

# %% [markdown]
# #### MobileNetV2 Model

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=[256,256,3], include_top=False)

# Use the activations of these layers
layer_names = [
    'block_1_expand_relu',   # 64x64
    'block_3_expand_relu',   # 32x32
    'block_6_expand_relu',   # 16x16
    'block_13_expand_relu',  # 8x8
    'block_16_project',      # 4x4
    ]
base_model_outputs = [base_model.get_layer(name).output for name in layer_names]

# Create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=base_model_outputs)
down_stack.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
def upsample(filters, size, norm_type='batchnorm', apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)    
    result = tf.keras.Sequential()
    result.add(tf.keras.layers.Conv2DTranspose(filters, size, strides=2, padding='same', kernel_initializer=initializer, use_bias=False))

    if norm_type.lower() == 'batchnorm':
        result.add(tf.keras.layers.BatchNormalization())
    elif norm_type.lower() == 'instancenorm':
        result.add(InstanceNormalization())
    if apply_dropout:
        result.add(tf.keras.layers.Dropout(0.5))
        result.add(tf.keras.layers.ReLU())
    return result

up_stack = [
    upsample(512, 3),  # 4x4 -> 8x8
    upsample(256, 3),  # 8x8 -> 16x16
    upsample(128, 3),  # 16x16 -> 32x32
    upsample(64, 3),   # 32x32 -> 64x64
    ]

# %%
def unet_model(output_channels):
    inputs = tf.keras.layers.Input(shape=[256,256,3])

  # Downsampling through the model
    skips = down_stack(inputs)
    x = skips[-1]
    skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        concat = tf.keras.layers.Concatenate()
        x = concat([x, skip])

  # This is the last layer of the model
    last = tf.keras.layers.Conv2DTranspose(
      output_channels, 3, strides=2, activation='sigmoid',
      padding='same')  #64x64 -> 128x128
    x = last(x)
    
    return tf.keras.Model(inputs=inputs, outputs=x)

# %% [markdown]
# #### Train the model

# %%
def dice(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis=0)

def dice_loss(in_gt, in_pred):
    return 1 - dice(in_gt, in_pred)

def iou(y_true, y_pred):
    y_true = tf.keras.backend.flatten(y_true)
    y_pred = tf.keras.backend.flatten(y_pred)
    y_true_f = tf.cast(y_true, tf.float32)
    y_pred_f = tf.cast(y_pred, tf.float32)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    union = tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) - intersection
    return (intersection + 1e-7) / (union + 1e-7)

def iou_loss(y_true, y_pred):
    return 1.0 - iou(y_true, y_pred)

# %%
def visualize(display_list):
    plt.figure(figsize=(12,12))
    title = ['Input Image', 'Predicted Mask', 'True Mask']
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]))
        plt.axis('off')
    plt.show()

def show_predictions(model, sample_image, sample_mask):
    pred_mask = model.predict(sample_image[tf.newaxis, ...])
    pred_mask = pred_mask.reshape(img_size[0],img_size[1],1)
    visualize([sample_image, pred_mask, sample_mask])

# %%
class DisplayCallback(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        if (epoch + 1) % 3 == 0:
            show_predictions(sample_image, sample_mask)
            
model_config = dict(
    unet_model_iou = [lambda *args: unet_model(*args), [iou_loss], [iou, "binary_accuracy"], "adam" , 1],
    unet_model_dice = [lambda *args: unet_model(*args), [dice_loss], [dice, "binary_accuracy"], "adam" , 1]
)

for model_name, (model_fn, model_loss, model_metrics, model_loss_fn, batch_size) in model_config.items():
    experiment_name = f"{model_name}_{str(datetime.datetime.now())}"
    experiment_path = pathlib.Path(f"./logs/{experiment_name}")
    checkpoint_name = f"{model_name}"
    checkpoint_path = pathlib.Path(f"./checkpoints/{checkpoint_name}")
    model = model_fn(1)
    model.compile(optimizer= model_loss_fn,
                  loss = model_loss,
                  metrics= model_metrics)            
    if option_train:
        run = wandb.init(reinit = True , name = experiment_name , project = PROJECT_NAME, config = {
                  #"learning_rate": 0.001,
                  "epochs": EPOCHS ,
                  "batch_size": batch_size,
                  "optimizer" : model_loss_fn
        })        
        model_history = model.fit(train_dataset, epochs=EPOCHS,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              batch_size = batch_size, 
                              validation_data=valid_dataset,
                              callbacks=[
                                  #DisplayCallback(),
                                  WandbCallback(),
                                  tf.keras.callbacks.TensorBoard(log_dir=experiment_path,
                                                                 histogram_freq=0,
                                                                 write_graph=True,
                                                                 write_images=True),
                                  tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                                 save_weights_only=True,
                                                                 monitor="val_loss",
                                                                 save_best_only=True,
                                                                 mode='auto')                              
                              ])
        run.finish()
# Out:
# wandb version 0.13.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/home/benteb13/Fish/Test/wandb/run-20230213_114759-2qyicfnw</code>
# Syncing run <strong><a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/2qyicfnw" target="_blank">unet_model_iou_2023-02-13 11:47:58.799070</a></strong> to <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# 2023-02-13 11:48:04.888687: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 11:48:04.888765: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
# 2023-02-13 11:48:04.888879: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1630] Profiler found 1 GPUs
# 2023-02-13 11:48:05.079944: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 11:48:05.080214: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 1/150
# 2023-02-13 11:48:12.491183: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
#   1/101 [..............................] - ETA: 14:28 - loss: 0.8013 - iou: 0.1987 - binary_accuracy: 0.0000e+00
# 2023-02-13 11:48:14.055077: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 11:48:14.055111: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
#   2/101 [..............................] - ETA: 1:45 - loss: 0.7908 - iou: 0.2092 - binary_accuracy: 0.0000e+00
# 2023-02-13 11:48:14.999386: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2023-02-13 11:48:14.999997: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# 2023-02-13 11:48:15.061973: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:526]  GpuTracer has collected 4884 callback api events and 3515 activity events.
# 2023-02-13 11:48:15.107386: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 11:48:15.172249: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/unet_model_iou_2023-02-13 11:47:58.799070/train/plugins/profile/2023_02_13_11_48_15
#   3/101 [..............................] - ETA: 1:09 - loss: 0.7720 - iou: 0.2280 - binary_accuracy: 0.0000e+00
ic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_114759-2qyicfnw/files/model-best)... Done. 0.3s
# Epoch 3/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.6610 - iou: 0.3391 - binary_accuracy: 0.0000e+00 - val_loss: 0.6329 - val_iou: 0.3670 - val_binary_accuracy: 0.6919
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_114759-2qyicfnw/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_114759-2qyicfnw/files/model-best)... Done. 0.3s
# Epoch 4/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.6602 - iou: 0.3395 - binary_accuracy: 0.0000e+00 - val_loss: 0.7348 - val_iou: 0.2652 - val_binary_accuracy: 0.4859
# Epoch 5/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.6603 - iou: 0.3395 - binary_accuracy: 0.0000e+00 - val_loss: 0.6905 - val_iou: 0.3095 - val_binary_accuracy: 0.5915
# Epoch 6/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6599 - iou: 0.3402 - binary_accuracy: 0.0000e+00 - val_loss: 0.7331 - val_iou: 0.2669 - val_binary_accuracy: 0.4914
# Epoch 7/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6581 - iou: 0.3418 - binary_accuracy: 0.0000e+00 - val_loss: 0.7389 - val_iou: 0.2611 - val_binary_accuracy: 0.4751
# Epoch 8/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.6593 - iou: 0.3406 - binary_accuracy: 0.0000e+00 - val_loss: 0.7404 - val_iou: 0.2597 - val_binary_accuracy: 0.4713
# Epoch 9/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6581 - iou: 0.3415 - binary_accuracy: 0.0000e+00 - val_loss: 0.7167 - val_iou: 0.2833 - val_binary_accuracy: 0.5331
# Epoch 10/150
# 101/101 [==============================] - 5s 55ms/step - loss: 0.6601 - iou: 0.3403 - binary_accuracy: 0.0000e+00 - val_loss: 0.7427 - val_iou: 0.2574 - val_binary_accuracy: 0.4646
# Epoch 11/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.6582 - iou: 0.3418 - binary_accuracy: 0.0000e+00 - val_loss: 0.7263 - val_iou: 0.2736 - val_binary_accuracy: 0.5089
# Epoch 12/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6580 - iou: 0.3418 - binary_accuracy: 0.0000e+00 - val_loss: 0.7003 - val_iou: 0.2997 - val_binary_accuracy: 0.5704
# Epoch 13/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6583 - iou: 0.3413 - binary_accuracy: 0.0000e+00 - val_loss: 0.7604 - val_iou: 0.2397 - val_binary_accuracy: 0.4098
# Epoch 14/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.6595 - iou: 0.3399 - binary_accuracy: 0.0000e+00 - val_loss: 0.7270 - val_iou: 0.2730 - val_binary_accuracy: 0.5086
# Epoch 15/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6574 - iou: 0.3426 - binary_accuracy: 0.0000e+00 - val_loss: 0.7806 - val_iou: 0.2195 - val_binary_accuracy: 0.3379
# Epoch 16/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.6582 - iou: 0.3422 - binary_accuracy: 0.0000e+00 - val_loss: 0.7286 - val_iou: 0.2714 - val_binary_accuracy: 0.5048
# Epoch 17/150
150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6557 - iou: 0.3442 - binary_accuracy: 0.0000e+00 - val_loss: 0.7476 - val_iou: 0.2524 - val_binary_accuracy: 0.4526
# Epoch 144/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6557 - iou: 0.3440 - binary_accuracy: 0.0000e+00 - val_loss: 0.7037 - val_iou: 0.2963 - val_binary_accuracy: 0.5645
# Epoch 145/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6575 - iou: 0.3420 - binary_accuracy: 0.0000e+00 - val_loss: 0.6940 - val_iou: 0.3060 - val_binary_accuracy: 0.5850
# Epoch 146/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.6570 - iou: 0.3427 - binary_accuracy: 0.0000e+00 - val_loss: 0.7337 - val_iou: 0.2664 - val_binary_accuracy: 0.4922
# Epoch 147/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.6569 - iou: 0.3427 - binary_accuracy: 0.0000e+00 - val_loss: 0.7263 - val_iou: 0.2737 - val_binary_accuracy: 0.5117
# Epoch 148/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.6547 - iou: 0.3453 - binary_accuracy: 0.0000e+00 - val_loss: 0.7134 - val_iou: 0.2866 - val_binary_accuracy: 0.5431
# Epoch 149/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.6572 - iou: 0.3430 - binary_accuracy: 0.0000e+00 - val_loss: 0.7481 - val_iou: 0.2519 - val_binary_accuracy: 0.4509
# Epoch 150/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.6561 - iou: 0.3437 - binary_accuracy: 0.0000e+00 - val_loss: 0.7259 - val_iou: 0.2741 - val_binary_accuracy: 0.5122
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>binary_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>iou</td><td>▁▃▄▅▅▅▄▅▆▆▅▅▆▅▅▅▆▅█▇▇▅▅▆▆▆▆▆▆▇▆▆▆▅▄▃▆▇▅▆</td></tr><tr><td>loss</td><td>█▆▅▄▄▄▅▄▃▃▄▄▃▄▄▃▄▄▁▂▂▄▃▃▃▃▃▃▃▂▃▃▃▄▅▆▃▂▃▃</td></tr><tr><td>val_binary_accuracy</td><td>▇▄▃█▅▅▆▄▄▆▇▄▃▄▆▅▅▃▃▅▅▆▃▂▅▃▅█▇▄▄▃▅▃▁▆▄▅▄▅</td></tr><tr><td>val_iou</td><td>▇▄▃█▄▅▆▃▄▅▆▄▂▄▅▅▄▂▂▅▅▅▃▂▅▂▅█▇▄▃▂▅▃▁▆▄▄▄▅</td></tr><tr><td>val_loss</td><td>▂▅▆▁▅▄▃▆▅▄▃▅▇▅▄▄▅▇▇▄▄▄▆▇▄▇▄▁▂▅▆▇▄▆█▃▅▅▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.63285</td></tr><tr><td>binary_accuracy</td><td>0.0</td></tr><tr><td>epoch</td><td>149</td></tr><tr><td>iou</td><td>0.34374</td></tr><tr><td>loss</td><td>0.65608</td></tr><tr><td>val_binary_accuracy</td><td>0.51219</td></tr><tr><td>val_iou</td><td>0.27411</td></tr><tr><td>val_loss</td><td>0.72589</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">unet_model_iou_2023-02-13 11:47:58.799070</strong>: <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/2qyicfnw" target="_blank">https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/2qyicfnw</a><br/>Synced 5 W&B file(s), 1 media file(s), 10 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20230213_114759-2qyicfnw/logs</code>
# Upgrade to the 0.27.0 version of W&B Server to get the latest features. Learn more: <a href="https://wandb.me/server-upgrade" target="_blank">https://wandb.me/server-upgrade</a>
# wandb version 0.13.10 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.7
# Run data is saved locally in <code>/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s</code>
# Syncing run <strong><a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/2k5vlw8s" target="_blank">unet_model_dice_2023-02-13 12:02:42.211118</a></strong> to <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# 2023-02-13 12:02:43.873971: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 12:02:43.874032: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
# 2023-02-13 12:02:44.670911: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 12:02:44.671164: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# Epoch 1/150
#   1/101 [..............................] - ETA: 3:46 - loss: 0.5795 - dice: 0.4205 - binary_accuracy: 0.0000e+00
# 2023-02-13 12:02:47.341233: I tensorflow/core/profiler/lib/profiler_session.cc:110] Profiler session initializing.
# 2023-02-13 12:02:47.341271: I tensorflow/core/profiler/lib/profiler_session.cc:125] Profiler session started.
#   3/101 [..............................] - ETA: 57s - loss: 0.5612 - dice: 0.4388 - binary_accuracy: 0.0000e+00
# 2023-02-13 12:02:48.249472: I tensorflow/core/profiler/lib/profiler_session.cc:67] Profiler session collecting data.
# 2023-02-13 12:02:48.250228: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1765] CUPTI activity buffer flushed
# 2023-02-13 12:02:48.277635: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:526]  GpuTracer has collected 408 callback api events and 406 activity events.
# 2023-02-13 12:02:48.287837: I tensorflow/core/profiler/lib/profiler_session.cc:143] Profiler session tear down.
# 2023-02-13 12:02:48.298664: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48
#
# 2023-02-13 12:02:48.306103: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48/jupyter-benteb13.trace.json.gz
# 2023-02-13 12:02:48.334293: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48
#
# 2023-02-13 12:02:48.339146: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48/jupyter-benteb13.memory_profile.json.gz
# 2023-02-13 12:02:48.340142: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48
# Dumped tool data for xplane.pb to logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48/jupyter-benteb13.xplane.pb
# Dumped tool data for overview_page.pb to logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48/jupyter-benteb13.overview_page.pb
# Dumped tool data for input_pipeline.pb to logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48/jupyter-benteb13.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48/jupyter-benteb13.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to logs/unet_model_dice_2023-02-13 12:02:42.211118/train/plugins/profile/2023_02_13_12_02_48/jupyter-benteb13.kernel_stats.pb
#   5/101 [>.............................] - ETA: 30s - loss: 0.5582 - dice: 0.4418 - binary_accuracy: 0.0000e+00WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0273s vs `on_train_batch_begin` time: 0.1073s). Check your callbacks.
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0273s vs `on_train_batch_end` time: 0.0860s). Check your callbacks.
# 101/101 [==============================] - 10s 73ms/step - loss: 0.5215 - dice: 0.4785 - binary_accuracy: 0.0000e+00 - val_loss: 0.6822 - val_dice: 0.3179 - val_binary_accuracy: 0.1959
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.4s
# Epoch 2/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5175 - dice: 0.4824 - binary_accuracy: 0.0000e+00 - val_loss: 0.6287 - val_dice: 0.3714 - val_binary_accuracy: 0.3767
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.3s
# Epoch 3/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5137 - dice: 0.4862 - binary_accuracy: 0.0000e+00 - val_loss: 0.5694 - val_dice: 0.4307 - val_binary_accuracy: 0.5295
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.4s
# Epoch 4/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5100 - dice: 0.4896 - binary_accuracy: 0.0000e+00 - val_loss: 0.4311 - val_dice: 0.5689 - val_binary_accuracy: 0.7402
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.3s
# Epoch 5/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.5078 - dice: 0.4920 - binary_accuracy: 0.0000e+00 - val_loss: 0.4146 - val_dice: 0.5854 - val_binary_accuracy: 0.7522
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.3s
# Epoch 6/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5073 - dice: 0.4929 - binary_accuracy: 0.0000e+00 - val_loss: 0.4155 - val_dice: 0.5845 - val_binary_accuracy: 0.7486
# Epoch 7/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5074 - dice: 0.4928 - binary_accuracy: 0.0000e+00 - val_loss: 0.3815 - val_dice: 0.6184 - val_binary_accuracy: 0.7819
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.3s
# Epoch 8/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5061 - dice: 0.4940 - binary_accuracy: 0.0000e+00 - val_loss: 0.4038 - val_dice: 0.5961 - val_binary_accuracy: 0.7585
# Epoch 9/150
# 101/101 [==============================] - 6s 55ms/step - loss: 0.5076 - dice: 0.4923 - binary_accuracy: 0.0000e+00 - val_loss: 0.3697 - val_dice: 0.6303 - val_binary_accuracy: 0.7914
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# ...
# Epoch 87/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5049 - dice: 0.4948 - binary_accuracy: 0.0000e+00 - val_loss: 0.2735 - val_dice: 0.7266 - val_binary_accuracy: 0.8686
# Epoch 88/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5056 - dice: 0.4944 - binary_accuracy: 0.0000e+00 - val_loss: 0.2723 - val_dice: 0.7278 - val_binary_accuracy: 0.8692
150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5055 - dice: 0.4943 - binary_accuracy: 0.0000e+00 - val_loss: 0.2660 - val_dice: 0.7341 - val_binary_accuracy: 0.8740
# Epoch 106/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5058 - dice: 0.4940 - binary_accuracy: 0.0000e+00 - val_loss: 0.2698 - val_dice: 0.7303 - val_binary_accuracy: 0.8707
# Epoch 107/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5055 - dice: 0.4947 - binary_accuracy: 0.0000e+00 - val_loss: 0.2361 - val_dice: 0.7640 - val_binary_accuracy: 0.8941
# Epoch 108/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5056 - dice: 0.4947 - binary_accuracy: 0.0000e+00 - val_loss: 0.2544 - val_dice: 0.7457 - val_binary_accuracy: 0.8815
# Epoch 109/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5057 - dice: 0.4940 - binary_accuracy: 0.0000e+00 - val_loss: 0.2594 - val_dice: 0.7407 - val_binary_accuracy: 0.8794
# Epoch 110/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5056 - dice: 0.4947 - binary_accuracy: 0.0000e+00 - val_loss: 0.2491 - val_dice: 0.7510 - val_binary_accuracy: 0.8860
# Epoch 111/150
# 101/101 [==============================] - 5s 50ms/step - loss: 0.5057 - dice: 0.4944 - binary_accuracy: 0.0000e+00 - val_loss: 0.2551 - val_dice: 0.7450 - val_binary_accuracy: 0.8812
# Epoch 112/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5052 - dice: 0.4951 - binary_accuracy: 0.0000e+00 - val_loss: 0.2433 - val_dice: 0.7568 - val_binary_accuracy: 0.8890
# Epoch 113/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5060 - dice: 0.4942 - binary_accuracy: 0.0000e+00 - val_loss: 0.2703 - val_dice: 0.7298 - val_binary_accuracy: 0.8707
# Epoch 114/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5053 - dice: 0.4945 - binary_accuracy: 0.0000e+00 - val_loss: 0.2440 - val_dice: 0.7561 - val_binary_accuracy: 0.8884
# Epoch 115/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5053 - dice: 0.4946 - binary_accuracy: 0.0000e+00 - val_loss: 0.2464 - val_dice: 0.7537 - val_binary_accuracy: 0.8874
# Epoch 116/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5063 - dice: 0.4937 - binary_accuracy: 0.0000e+00 - val_loss: 0.2381 - val_dice: 0.7619 - val_binary_accuracy: 0.8925
# Epoch 117/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5053 - dice: 0.4947 - binary_accuracy: 0.0000e+00 - val_loss: 0.2871 - val_dice: 0.7130 - val_binary_accuracy: 0.8588
# Epoch 118/150
# 101/101 [==============================] - 5s 50ms/step - loss: 0.5051 - dice: 0.4952 - binary_accuracy: 0.0000e+00 - val_loss: 0.2658 - val_dice: 0.7343 - val_binary_accuracy: 0.8736
# Epoch 119/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.5059 - dice: 0.4941 - binary_accuracy: 0.0000e+00 - val_loss: 0.2675 - val_dice: 0.7327 - val_binary_accuracy: 0.8720
# Epoch 120/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5046 - dice: 0.4952 - binary_accuracy: 0.0000e+00 - val_loss: 0.2406 - val_dice: 0.7594 - val_binary_accuracy: 0.8905
# Epoch 121/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5062 - dice: 0.4938 - binary_accuracy: 0.0000e+00 - val_loss: 0.2455 - val_dice: 0.7546 - val_binary_accuracy: 0.8874
# Epoch 122/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5060 - dice: 0.4938 - binary_accuracy: 0.0000e+00 - val_loss: 0.2551 - val_dice: 0.7450 - val_binary_accuracy: 0.8822
# Epoch 123/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5057 - dice: 0.4945 - binary_accuracy: 0.0000e+00 - val_loss: 0.2439 - val_dice: 0.7562 - val_binary_accuracy: 0.8887
# Epoch 124/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5039 - dice: 0.4962 - binary_accuracy: 0.0000e+00 - val_loss: 0.2697 - val_dice: 0.7304 - val_binary_accuracy: 0.8710
# Epoch 125/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5060 - dice: 0.4943 - binary_accuracy: 0.0000e+00 - val_loss: 0.2363 - val_dice: 0.7637 - val_binary_accuracy: 0.8944
# Epoch 126/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5057 - dice: 0.4947 - binary_accuracy: 0.0000e+00 - val_loss: 0.2769 - val_dice: 0.7233 - val_binary_accuracy: 0.8663
# Epoch 127/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5044 - dice: 0.4957 - binary_accuracy: 0.0000e+00 - val_loss: 0.2593 - val_dice: 0.7408 - val_binary_accuracy: 0.8792
# Epoch 128/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5066 - dice: 0.4934 - binary_accuracy: 0.0000e+00 - val_loss: 0.2498 - val_dice: 0.7503 - val_binary_accuracy: 0.8844
# Epoch 129/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5054 - dice: 0.4947 - binary_accuracy: 0.0000e+00 - val_loss: 0.2377 - val_dice: 0.7624 - val_binary_accuracy: 0.8926
# Epoch 130/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5074 - dice: 0.4927 - binary_accuracy: 0.0000e+00 - val_loss: 0.2451 - val_dice: 0.7551 - val_binary_accuracy: 0.8876
# Epoch 131/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5041 - dice: 0.4956 - binary_accuracy: 0.0000e+00 - val_loss: 0.2594 - val_dice: 0.7407 - val_binary_accuracy: 0.8787
# Epoch 132/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5048 - dice: 0.4950 - binary_accuracy: 0.0000e+00 - val_loss: 0.2314 - val_dice: 0.7687 - val_binary_accuracy: 0.8968
# Epoch 133/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5071 - dice: 0.4929 - binary_accuracy: 0.0000e+00 - val_loss: 0.2652 - val_dice: 0.7350 - val_binary_accuracy: 0.8747
# Epoch 134/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5044 - dice: 0.4954 - binary_accuracy: 0.0000e+00 - val_loss: 0.2542 - val_dice: 0.7459 - val_binary_accuracy: 0.8816
# Epoch 135/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5054 - dice: 0.4950 - binary_accuracy: 0.0000e+00 - val_loss: 0.2463 - val_dice: 0.7538 - val_binary_accuracy: 0.8872
# Epoch 136/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5066 - dice: 0.4932 - binary_accuracy: 0.0000e+00 - val_loss: 0.2299 - val_dice: 0.7702 - val_binary_accuracy: 0.8975
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.3s
# Epoch 137/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5048 - dice: 0.4952 - binary_accuracy: 0.0000e+00 - val_loss: 0.2536 - val_dice: 0.7465 - val_binary_accuracy: 0.8821
# Epoch 138/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5047 - dice: 0.4953 - binary_accuracy: 0.0000e+00 - val_loss: 0.2381 - val_dice: 0.7620 - val_binary_accuracy: 0.8923
# Epoch 139/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5056 - dice: 0.4945 - binary_accuracy: 0.0000e+00 - val_loss: 0.2447 - val_dice: 0.7553 - val_binary_accuracy: 0.8886
# Epoch 140/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5047 - dice: 0.4951 - binary_accuracy: 0.0000e+00 - val_loss: 0.2475 - val_dice: 0.7526 - val_binary_accuracy: 0.8866
# Epoch 141/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5068 - dice: 0.4931 - binary_accuracy: 0.0000e+00 - val_loss: 0.2508 - val_dice: 0.7494 - val_binary_accuracy: 0.8841
# Epoch 142/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5063 - dice: 0.4935 - binary_accuracy: 0.0000e+00 - val_loss: 0.2380 - val_dice: 0.7620 - val_binary_accuracy: 0.8925
# Epoch 143/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5036 - dice: 0.4964 - binary_accuracy: 0.0000e+00 - val_loss: 0.2470 - val_dice: 0.7531 - val_binary_accuracy: 0.8874
# Epoch 144/150
# 101/101 [==============================] - 5s 51ms/step - loss: 0.5056 - dice: 0.4946 - binary_accuracy: 0.0000e+00 - val_loss: 0.2455 - val_dice: 0.7546 - val_binary_accuracy: 0.8877
# Epoch 145/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5061 - dice: 0.4938 - binary_accuracy: 0.0000e+00 - val_loss: 0.2321 - val_dice: 0.7679 - val_binary_accuracy: 0.8962
# Epoch 146/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5051 - dice: 0.4949 - binary_accuracy: 0.0000e+00 - val_loss: 0.2555 - val_dice: 0.7446 - val_binary_accuracy: 0.8810
# Epoch 147/150
# 101/101 [==============================] - 5s 54ms/step - loss: 0.5054 - dice: 0.4942 - binary_accuracy: 0.0000e+00 - val_loss: 0.2375 - val_dice: 0.7626 - val_binary_accuracy: 0.8936
# Epoch 148/150
# 101/101 [==============================] - 5s 53ms/step - loss: 0.5057 - dice: 0.4940 - binary_accuracy: 0.0000e+00 - val_loss: 0.2443 - val_dice: 0.7558 - val_binary_accuracy: 0.8886
# Epoch 149/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5067 - dice: 0.4934 - binary_accuracy: 0.0000e+00 - val_loss: 0.2254 - val_dice: 0.7747 - val_binary_accuracy: 0.9012
# INFO:tensorflow:Assets written to: /home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/benteb13/Fish/Test/wandb/run-20230213_120242-2k5vlw8s/files/model-best)... Done. 0.3s
# Epoch 150/150
# 101/101 [==============================] - 5s 52ms/step - loss: 0.5044 - dice: 0.4954 - binary_accuracy: 0.0000e+00 - val_loss: 0.2710 - val_dice: 0.7291 - val_binary_accuracy: 0.8705
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>binary_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>dice</td><td>▁▅▇▇▇▇▆▇▇▆▇▆▇▇▆█▇▇▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▆██▇▇█</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▂▂▂▂▃▂▂▃▂▃▂▂▃▁▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▂▂▃▁▂▂▂▁</td></tr><tr><td>val_binary_accuracy</td><td>▁▆▆▇▇▇▇▇▇████████████████▇██████████████</td></tr><tr><td>val_dice</td><td>▁▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█▇███▇█▇█████▇█▇█████▇</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▂▁▂▁▁▁▁▁▂▁▂▁▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>148</td></tr><tr><td>best_val_loss</td><td>0.22539</td></tr><tr><td>binary_accuracy</td><td>0.0</td></tr><tr><td>dice</td><td>0.49544</td></tr><tr><td>epoch</td><td>149</td></tr><tr><td>loss</td><td>0.50442</td></tr><tr><td>val_binary_accuracy</td><td>0.87051</td></tr><tr><td>val_dice</td><td>0.72911</td></tr><tr><td>val_loss</td><td>0.27104</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">unet_model_dice_2023-02-13 12:02:42.211118</strong>: <a href="https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/2k5vlw8s" target="_blank">https://wandb.ikt-lab.internal.uia.no/benteb13/FishTest_aug/runs/2k5vlw8s</a><br/>Synced 5 W&B file(s), 1 media file(s), 70 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20230213_120242-2k5vlw8s/logs</code>
# Upgrade to the 0.27.0 version of W&B Server to get the latest features. Learn more: <a href="https://wandb.me/server-upgrade" target="_blank">https://wandb.me/server-upgrade</a>

# %%
model.load_weights(checkpoint_path)

# %%
#Show sample images in test dataset with their true mask and predicted mask after training
for i in range(5):
    for images, masks in test_dataset.take(i):
        for img, mask in zip(images, masks):
            tsample_image = img
            tsample_mask = mask
            show_predictions(model, tsample_image, tsample_mask)
            break

# %% [markdown]
# # Step 2

# %% [markdown]
# Use pre-trained model to predict fish in the wild

# %%
nor_fish_path = BASE_PATH.joinpath('Fish_Dataset/Norsk_Fisk')

nf_files =[]
nf_paths = []
nf_classes_paths = [x for x in list (nor_fish_path.glob("**/*")) if not x.name.startswith("_") and not x.name.startswith(".") and x.is_dir()]
for nf_class_path in nf_classes_paths:
    nf_class_images = list(nf_class_path.glob("*.PNG"))
    nf_class_names = [x.name for x in nf_class_images]
    nf_files.extend(nf_class_names)
    nf_paths.extend([str(x.absolute()) for x in nf_class_images])

# %%
nf_df = pd.DataFrame()
nf_df['label'] = 1
nf_df['file'] = nf_files
nf_df['path'] = nf_paths
nf_df['mpath'] = nf_paths

display(nf_df)
# Out:
#       label      file                                               path  \
# 0       NaN   128.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1       NaN    13.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 2       NaN   185.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 3       NaN    50.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 4       NaN    99.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# ...     ...       ...                                                ...
# 1304    NaN  4-11.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1305    NaN  4-21.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1306    NaN   4-8.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1307    NaN  4-17.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1308    NaN  4-25.PNG  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
#
#                                                   mpath
# 0     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 2     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 3     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 4     /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# ...                                                 ...
# 1304  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1305  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1306  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1307  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
# 1308  /home/benteb13/Fish/Test/Fish_Dataset/Norsk_Fi...
#
# [1309 rows x 4 columns]

# %%
nf_dataset = create_dataset(nf_df, train = False)

for i in range(5):
    for images, masks in nf_dataset.take(i):        
        pred_mask = model.predict(images[tf.newaxis, ...])
        pred_mask = pred_mask.reshape(img_size[0],img_size[1],1)
        visualize([images, pred_mask])
